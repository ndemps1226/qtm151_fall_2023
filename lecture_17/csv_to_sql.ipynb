# %% [markdown]
# # <span style="color:darkblue"> Import CSV into SQL </span>

# %%
import pandas as pd
from sqlalchemy import create_engine
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %% [markdown]
# <font size = "5">
#
# **Step 1:** read the CSV file you want to upload into SQL

# %%
members = pd.read_csv('data/us_congress_members.csv')
members
# Out:
#       member_id                 full_name   last_name    member_title  \
# 0             0        A. Donald McEachin    McEachin  Representative
# 1             1              Aaron Schock      Schock  Representative
# 2             2           Abby Finkenauer  Finkenauer  Representative
# 3             3  Abigail Davis Spanberger  Spanberger  Representative
# 4             4            Adam H. Putnam      Putnam  Representative
# ...         ...                       ...         ...             ...
# 1806       1806             Wm. Lacy Clay        Clay  Representative
# 1807       1807         Wyche, Jr. Fowler      Fowler         Senator
# 1808       1808         Wyche, Jr. Fowler      Fowler         Senator
# 1809       1809          Yvette D. Clarke      Clarke  Representative
# 1810       1810               Zell Miller      Miller         Senator
#
#          state  party_name chamber
# 0     Virginia  Democratic   House
# 1     Illinois  Republican   House
# 2         Iowa  Democratic   House
# 3     Virginia  Democratic   House
# 4      Florida  Republican   House
# ...        ...         ...     ...
# 1806  Missouri  Democratic   House
# 1807   Georgia  Democratic   House
# 1808   Georgia  Democratic  Senate
# 1809  New York  Democratic   House
# 1810   Georgia  Democratic  Senate
#
# [1811 rows x 7 columns]

# %% [markdown]
# <font size = "5">
#
# **Step 2:** create a new SQL connection using the function ```create_engine```
#
# - Make sure you specify your password (in my case 12345), followed by the name of the server (localhost in my case) and the port where the server is listening (5432 in my case)
#
# - Input the name of the database after the slash following the port number (we will use the new ```us_congress``` database)
#
# - The ```connect_args``` option allows us to change the schema where we will upload the CSV data (for this example it is members)

# %%
engine = create_engine('postgresql://postgres:12345@localhost:5432/us_congress', connect_args={'options': '-csearch_path=members'})
engine
# Out:
# Engine(postgresql://postgres:***@localhost:5432/us_congress)

# %% [markdown]
# <font size = "5">
#
# **Step 3:** upload the CSV table to SQL using the ```to_sql``` function:
#
# - First input is the name you want to give to the table
#
# - The second input is the engine we created in the previous step

# %%
members.to_sql('us_congress_members', con = engine, if_exists='replace', index=False)
# Out:
# 811

# %% [markdown]
# <font size = "5">
#
# Try it yourself!
#
# - Import the table "bills_subjects.csv" using the procedure described above
#
# - Import the table "bills_actions.csv" using the procedure described above

# %%
# Write your code here
bills = pd.read_csv('data/bills_subjects.csv')
engine = create_engine('postgresql://postgres:12345@localhost:5432/us_congress', connect_args={'options': '-csearch_path=bills'})
bills.to_sql('bills_subjects', con = engine, if_exists='replace', index=False)

subjects
# Out:
#         congress  bill_number bill_type  \
# 0            116           81   hconres
# 1            116           81   hconres
# 2            116           83   hconres
# 3            116           83   hconres
# 4            116           83   hconres
# ...          ...          ...       ...
# 158693       116         2474         s
# 158694       116         2474         s
# 158695       116         2474         s
# 158696       116         2474         s
# 158697       116         2474         s
#
#                                            bill_subject
# 0                                        Appropriations
# 1                       Legislative rules and procedure
# 2                                    Conflicts and wars
# 3                               Congressional oversight
# 4                                                  Iran
# ...                                                 ...
# 158693  Veterans' education, employment, rehabilitation
# 158694                           Veterans' medical care
# 158695                         War and emergency powers
# 158696                                 Washington State
# 158697                                            Yemen
#
# [158698 rows x 4 columns]

# %%
actions = pd.read_csv('data/bills_actions.csv')
engine = create_engine('postgresql://postgres:12345@localhost:5432/us_congress', connect_args={'options': '-csearch_path=actions'})
actions.to_sql('bills_actions', con = engine, if_exists='replace', index=False)

actions
# Out:
# ---------------------------------------------------------------------------
# InvalidSchemaName                         Traceback (most recent call last)
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# InvalidSchemaName: no schema has been selected to create in
# LINE 2: CREATE TABLE bills_actions (
#                      ^
#
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# /Users/nylademps/QTM 151/GitHub/qtm151_fall_2023/lecture_17/csv_to_sql.ipynb Cell 11 line 3
#       <a href='vscode-notebook-cell:/Users/nylademps/QTM%20151/GitHub/qtm151_fall_2023/lecture_17/csv_to_sql.ipynb#X13sZmlsZQ%3D%3D?line=0'>1</a> actions = pd.read_csv('data/bills_actions.csv')
#       <a href='vscode-notebook-cell:/Users/nylademps/QTM%20151/GitHub/qtm151_fall_2023/lecture_17/csv_to_sql.ipynb#X13sZmlsZQ%3D%3D?line=1'>2</a> engine = create_engine('postgresql://postgres:12345@localhost:5432/us_congress', connect_args={'options': '-csearch_path=actions'})
# ----> <a href='vscode-notebook-cell:/Users/nylademps/QTM%20151/GitHub/qtm151_fall_2023/lecture_17/csv_to_sql.ipynb#X13sZmlsZQ%3D%3D?line=2'>3</a> actions.to_sql('bills_actions', con = engine, if_exists='replace', index=False)
#       <a href='vscode-notebook-cell:/Users/nylademps/QTM%20151/GitHub/qtm151_fall_2023/lecture_17/csv_to_sql.ipynb#X13sZmlsZQ%3D%3D?line=4'>5</a> actions
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/core/generic.py:2878, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2713 """
#    2714 Write records stored in a DataFrame to a SQL database.
#    2715
#    (...)
#    2874 [(1,), (None,), (2,)]
#    2875 """  # noqa:E501
#    2876 from pandas.io import sql
# -> 2878 return sql.to_sql(
#    2879     self,
#    2880     name,
#    2881     con,
#    2882     schema=schema,
#    2883     if_exists=if_exists,
#    2884     index=index,
#    2885     index_label=index_label,
#    2886     chunksize=chunksize,
#    2887     dtype=dtype,
#    2888     method=method,
#    2889 )
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/io/sql.py:769, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     764     raise NotImplementedError(
#     765         "'frame' argument should be either a Series or a DataFrame"
#     766     )
#     768 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 769     return pandas_sql.to_sql(
#     770         frame,
#     771         name,
#     772         if_exists=if_exists,
#     773         index=index,
#     774         index_label=index_label,
#     775         schema=schema,
#     776         chunksize=chunksize,
#     777         dtype=dtype,
#     778         method=method,
#     779         engine=engine,
#     780         **engine_kwargs,
#     781     )
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/io/sql.py:1910, in SQLDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    1860 """
#    1861 Write records stored in a DataFrame to a SQL database.
#    1862
#    (...)
#    1906     Any additional kwargs are passed to the engine.
#    1907 """
#    1908 sql_engine = get_engine(engine)
# -> 1910 table = self.prep_table(
#    1911     frame=frame,
#    1912     name=name,
#    1913     if_exists=if_exists,
#    1914     index=index,
#    1915     index_label=index_label,
#    1916     schema=schema,
#    1917     dtype=dtype,
#    1918 )
#    1920 total_inserted = sql_engine.insert_records(
#    1921     table=table,
#    1922     con=self.con,
#    (...)
#    1929     **engine_kwargs,
#    1930 )
#    1932 self.check_case_sensitive(name=name, schema=schema)
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/io/sql.py:1814, in SQLDatabase.prep_table(self, frame, name, if_exists, index, index_label, schema, dtype)
#    1802             raise ValueError(f"The type of {col} is not a SQLAlchemy type")
#    1804 table = SQLTable(
#    1805     name,
#    1806     self,
#    (...)
#    1812     dtype=dtype,
#    1813 )
# -> 1814 table.create()
#    1815 return table
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/io/sql.py:914, in SQLTable.create(self)
#     912         raise ValueError(f"'{self.if_exists}' is not valid for if_exists")
#     913 else:
# --> 914     self._execute_create()
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/pandas/io/sql.py:900, in SQLTable._execute_create(self)
#     898 self.table = self.table.to_metadata(self.pd_sql.meta)
#     899 with self.pd_sql.run_transaction():
# --> 900     self.table.create(bind=self.pd_sql.con)
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/sql/schema.py:1293, in Table.create(self, bind, checkfirst)
#    1281 def create(self, bind: _CreateDropBind, checkfirst: bool = False) -> None:
#    1282     """Issue a ``CREATE`` statement for this
#    1283     :class:`_schema.Table`, using the given
#    1284     :class:`.Connection` or :class:`.Engine`
#    (...)
#    1290
#    1291     """
# -> 1293     bind._run_ddl_visitor(ddl.SchemaGenerator, self, checkfirst=checkfirst)
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2443, in Connection._run_ddl_visitor(self, visitorcallable, element, **kwargs)
#    2431 def _run_ddl_visitor(
#    2432     self,
#    2433     visitorcallable: Type[Union[SchemaGenerator, SchemaDropper]],
#    2434     element: SchemaItem,
#    2435     **kwargs: Any,
#    2436 ) -> None:
#    2437     """run a DDL visitor.
#    2438
#    2439     This method is only here so that the MockConnection can change the
#    2440     options given to the visitor so that "checkfirst" is skipped.
#    2441
#    2442     """
# -> 2443     visitorcallable(self.dialect, self, **kwargs).traverse_single(element)
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/sql/visitors.py:670, in ExternalTraversal.traverse_single(self, obj, **kw)
#     668 meth = getattr(v, "visit_%s" % obj.__visit_name__, None)
#     669 if meth:
# --> 670     return meth(obj, **kw)
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:960, in SchemaGenerator.visit_table(self, table, create_ok, include_foreign_key_constraints, _is_metadata_operation)
#     951 if not self.dialect.supports_alter:
#     952     # e.g., don't omit any foreign key constraints
#     953     include_foreign_key_constraints = None
#     955 CreateTable(
#     956     table,
#     957     include_foreign_key_constraints=(
#     958         include_foreign_key_constraints
#     959     ),
# --> 960 )._invoke_with(self.connection)
#     962 if hasattr(table, "indexes"):
#     963     for index in table.indexes:
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:315, in ExecutableDDLElement._invoke_with(self, bind)
#     313 def _invoke_with(self, bind):
#     314     if self._should_execute(self.target, bind):
# --> 315         return bind.execute(self)
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1412, in Connection.execute(self, statement, parameters, execution_options)
#    1410     raise exc.ObjectNotExecutableError(statement) from err
#    1411 else:
# -> 1412     return meth(
#    1413         self,
#    1414         distilled_parameters,
#    1415         execution_options or NO_OPTIONS,
#    1416     )
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/sql/ddl.py:181, in ExecutableDDLElement._execute_on_connection(self, connection, distilled_params, execution_options)
#     178 def _execute_on_connection(
#     179     self, connection, distilled_params, execution_options
#     180 ):
# --> 181     return connection._execute_ddl(
#     182         self, distilled_params, execution_options
#     183     )
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1524, in Connection._execute_ddl(self, ddl, distilled_parameters, execution_options)
#    1519 dialect = self.dialect
#    1521 compiled = ddl.compile(
#    1522     dialect=dialect, schema_translate_map=schema_translate_map
#    1523 )
# -> 1524 ret = self._execute_context(
#    1525     dialect,
#    1526     dialect.execution_ctx_cls._init_ddl,
#    1527     compiled,
#    1528     None,
#    1529     execution_options,
#    1530     compiled,
#    1531 )
#    1532 if self._has_events or self.engine._has_events:
#    1533     self.dispatch.after_execute(
#    1534         self,
#    1535         ddl,
#    (...)
#    1539         ret,
#    1540     )
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1844, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1839     return self._exec_insertmany_context(
#    1840         dialect,
#    1841         context,
#    1842     )
#    1843 else:
# -> 1844     return self._exec_single_context(
#    1845         dialect, context, statement, parameters
#    1846     )
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1984, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1981     result = context._setup_result_proxy()
#    1983 except BaseException as e:
# -> 1984     self._handle_dbapi_exception(
#    1985         e, str_statement, effective_parameters, cursor, context
#    1986     )
#    1988 return result
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:2339, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2337 elif should_wrap:
#    2338     assert sqlalchemy_exception is not None
# -> 2339     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2340 else:
#    2341     assert exc_info[1] is not None
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/base.py:1965, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963                 break
#    1964     if not evt_handled:
# -> 1965         self.dialect.do_execute(
#    1966             cursor, str_statement, effective_parameters, context
#    1967         )
#    1969 if self._has_events or self.engine._has_events:
#    1970     self.dispatch.after_cursor_execute(
#    1971         self,
#    1972         cursor,
#    (...)
#    1976         context.executemany,
#    1977     )
#
# File ~/opt/anaconda3/envs/qtm151/lib/python3.11/site-packages/sqlalchemy/engine/default.py:921, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     920 def do_execute(self, cursor, statement, parameters, context=None):
# --> 921     cursor.execute(statement, parameters)
#
# ProgrammingError: (psycopg2.errors.InvalidSchemaName) no schema has been selected to create in
# LINE 2: CREATE TABLE bills_actions (
#                      ^
#
# [SQL:
# CREATE TABLE bills_actions (
# 	congress BIGINT,
# 	bill_number BIGINT,
# 	bill_type TEXT,
# 	action TEXT,
# 	main_action TEXT,
# 	object TEXT,
# 	member_id BIGINT
# )
#
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)
